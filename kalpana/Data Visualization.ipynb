# %% [markdown]
# # IMPORTING LIBRARIES

# %%
#Importing the libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Importing data into Python
import os
os.getcwd()
# Out:
# 'C:\\Users\\KALPANA  PATNALA\\Desktop\\Liver-Patients-Analysis'

# %%
os.chdir(r"C:\Users\KALPANA  PATNALA\Desktop\Liver-Patients-Analysis\Datasets")
os.getcwd()
# Out:
# 'C:\\Users\\KALPANA  PATNALA\\Desktop\\Liver-Patients-Analysis\\Datasets'

# %%
data=pd.read_csv(r'C:\Users\KALPANA  PATNALA\Desktop\Liver-Patients-Analysis\Datasets\indian_liver_patient.csv')

# %%
data
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
data.shape
# Out:
# (583, 11)

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                         int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
data['Albumin_and_Globulin_Ratio'].mean()
# Out:
# 0.9470639032815201

# %%
data.fillna(data.mean(),inplace=True)

# %%
data
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data['Gender'].hist(bins=10)

# %%
data['Age'].hist(bins=10)

# %%
data['Dataset'].hist(bins=10)# here we can observe that most of the people are effecting with liver disease

# %%
data['Total_Protiens'].hist(bins=10)

# %%
data['Total_Bilirubin'].hist(bins=10)

# %%
data['Direct_Bilirubin'].hist(bins=10)

# %%
data['Albumin_and_Globulin_Ratio'].hist(bins=10)

# %%
data['Alkaline_Phosphotase'].hist(bins=10)

# %%
data['Alamine_Aminotransferase'].hist(bins=10)

# %%
data['Aspartate_Aminotransferase'].hist(bins=10)

# %%
data.hist(column='Dataset',by='Gender',bins=10)# by this we can obsserve that females are not efected with the liver diesease most when compared to males
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021017D5E408>,
# ...
#       dtype=object)

# %%
data.hist(column='Total_Protiens',by='Dataset',bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021017E562C8>,
# ...
#       dtype=object)

# %%
data.boxplot(column='Age')

# %%
data.boxplot(column='Total_Bilirubin')

# %%
data.boxplot(column='Direct_Bilirubin')

# %%
data.boxplot(column='Alkaline_Phosphotase')

# %%
data.boxplot(column='Alamine_Aminotransferase')

# %%
data.boxplot(column='Aspartate_Aminotransferase')

# %%
data.boxplot(column='Total_Protiens')

# %%
data.boxplot(column='Albumin')

# %%
data.boxplot(column='Albumin_and_Globulin_Ratio')

# %%
data.boxplot(column='Dataset')

# %%
#Standard plotly imports
#to generate more interactive plots we use cufflinks and plotly
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot,init_notebook_mode #iplot means interactive plot

# %%
#Using plotly + cufflinks in offline mode
import cufflinks #supporting application library built on 
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
data[['Gender','Age']].iplot()
# Out:
# <div>
#
#
#             <div id="90acedbc-07c0-4121-b389-86a60b7f4769" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("90acedbc-07c0-4121-b389-86a60b7f4769")) {
#                     Plotly.newPlot(
#                         '90acedbc-07c0-4121-b389-86a60b7f4769',
# ...

# %%
data[['Total_Bilirubin','Direct_Bilirubin']].iplot()
# Out:
# <div>
#
#
#             <div id="cf48704e-e649-41b5-99b8-30559f1ba349" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cf48704e-e649-41b5-99b8-30559f1ba349")) {
#                     Plotly.newPlot(
#                         'cf48704e-e649-41b5-99b8-30559f1ba349',
# ...

# %%
data[['Aspartate_Aminotransferase','Alamine_Aminotransferase']].iplot()
# Out:
# <div>
#
#
#             <div id="1ae2e43a-4291-4b67-b4b3-d073fde534c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1ae2e43a-4291-4b67-b4b3-d073fde534c3")) {
#                     Plotly.newPlot(
#                         '1ae2e43a-4291-4b67-b4b3-d073fde534c3',
# ...

# %%
data[['Alkaline_Phosphotase','Alamine_Aminotransferase']].iplot()
# Out:
# <div>
#
#
#             <div id="65c9d682-eb60-4e3c-b704-a5d991473608" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("65c9d682-eb60-4e3c-b704-a5d991473608")) {
#                     Plotly.newPlot(
#                         '65c9d682-eb60-4e3c-b704-a5d991473608',
# ...

# %%
data[['Total_Protiens','Albumin']].iplot()
# Out:
# <div>
#
#
#             <div id="938602cf-2ce9-497c-bfc2-a444134fe7ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("938602cf-2ce9-497c-bfc2-a444134fe7ad")) {
#                     Plotly.newPlot(
#                         '938602cf-2ce9-497c-bfc2-a444134fe7ad',
# ...

# %%
data[['Albumin_and_Globulin_Ratio','Albumin']].iplot()
# Out:
# <div>
#
#
#             <div id="dee8049d-876d-4943-815d-80041e3444dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("dee8049d-876d-4943-815d-80041e3444dd")) {
#                     Plotly.newPlot(
#                         'dee8049d-876d-4943-815d-80041e3444dd',
# ...

# %%
import seaborn as sns
sns.pairplot(data)
